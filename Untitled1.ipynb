# %%
x(t)=t^2
y(t)=t^3
z(t)=t
u,v=var('u,v')
X=parametric_plot3d((x(u), y(u), v*z(u)+(1-v)*(-2)), (u,-1,1), (v,0,1),
                    opacity=1,
                    boundary_style={"color": "black", "thickness": 2,"plot_points":200},
                    frame=False,
                   plot_points=[200,200])
Y=parametric_plot3d((u,u*v,v),(u,-1,3),(v,-6,6))
plot(X)
# Out:
# Graphics3d Object

# %%
u, v = var('u,v')
parametric_plot3d((cos(u), sin(u)+cos(v), sin(v)), (u,0,2*pi), (v,-pi,pi), color='green', opacity=0.1, plot_points=[30,30])
# Out:
# Graphics3d Object
